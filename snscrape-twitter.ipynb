# %% [markdown]
# # Taking the first steps in snscrape land

# %% [markdown]
# **snscrape** is a scraper for social networking services (SNS). It scrapes things like user profiles, hashtags, or searches and returns the discovered items, e.g. the relevant posts.

# %% [markdown]
# Github repo: https://github.com/JustAnotherArchivist/snscrape

# %% [markdown]
# ## Scraping tweets from the terminal

# %%
# !pip install snscrape
# Out:
# Collecting snscrape
#   Downloading snscrape-0.4.3.20220106-py3-none-any.whl (59 kB)
# Requirement already satisfied: filelock in c:\users\devsn\anaconda3\lib\site-packages (from snscrape) (3.3.1)
# Requirement already satisfied: requests[socks] in c:\users\devsn\anaconda3\lib\site-packages (from snscrape) (2.26.0)
# Requirement already satisfied: lxml in c:\users\devsn\anaconda3\lib\site-packages (from snscrape) (4.6.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\devsn\anaconda3\lib\site-packages (from snscrape) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\devsn\anaconda3\lib\site-packages (from beautifulsoup4->snscrape) (2.2.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\devsn\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\devsn\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\devsn\anaconda3\lib\site-packages (from requests[socks]->snscrape) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\devsn\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\devsn\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.4.3.20220106

# %%
# !snscrape --help
# Out:
# usage: snscrape [-h] [--version] [--citation] [-v] [--dump-locals] [--retry N]
#                 [-n N] [-f FORMAT | --jsonl] [--with-entity]
#                 [--since DATETIME] [--progress]
#                 SCRAPER ...
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --version             show program's version number and exit
#   --citation            Display recommended citation information and exit
#                         (default: None)
#   -v, --verbose, --verbosity
#                         Increase output verbosity (default: 0)
#   --dump-locals         Dump local variables on serious log messages (warnings
#                         or higher) (default: False)
#   --retry N, --retries N
#                         When the connection fails or the server returns an
#                         unexpected response, retry up to N times with an
#                         exponential backoff (default: 3)
#   -n N, --max-results N
#                         Only return the first N results (default: None)
#   -f FORMAT, --format FORMAT
#                         Output format (default: None)
#   --jsonl               Output JSONL (default: False)
#   --with-entity         Include the entity (e.g. user, channel) as the first
#                         output item (default: False)
#   --since DATETIME      Only return results newer than DATETIME (default:
#                         None)
#   --progress            Report progress on stderr (default: False)
#
# scrapers:
#   SCRAPER
#     facebook-community
#     facebook-group
#     facebook-user
#     instagram-hashtag
#     instagram-location
#     instagram-user
#     mastodon-profile
#     mastodon-toot
#     reddit-search
#     reddit-subreddit
#     reddit-user
#     telegram-channel
#     twitter-hashtag
#     twitter-list-posts
#     twitter-profile
#     twitter-search
#     twitter-trends
#     twitter-tweet
#     twitter-user
#     vkontakte-user
#     weibo-user

# %% [markdown]
# There are multiple scrapers for twitter, based on use case.
# For scraping tweets of a particular user, the appropriate one to use is twitter-user.

# %%
# Return top 3 (most recent) @macmiller tweets 

# !snscrape --max-results 3 twitter-user macmiller
# Out:
# https://twitter.com/MacMiller/status/1037883095196680192
# https://twitter.com/MacMiller/status/1037879990090489856
# https://twitter.com/MacMiller/status/1037879124868517889

# %% [markdown]
# ## Using the official python wrapper to scrape tweets

# %% [markdown]
# The CLI usage of snscrape has been documented on the repo.
#
# However, the python wrapper has no official documentation. The information is passed on through blogs, and word of mouth probably, from what I can figure out.

# %%
# importing snscrape as a package in python

import snscrape.modules.twitter as sntwitter

# %%
# importing other libraries

import pandas as pd
import numpy as np
import itertools

# %% [markdown]
# To filter the data by location, snscrape accepts a geocode argument which requires three - latitude, longitude, and radius - values as inputs.

# %%
# assigning the latitude and longitude of London to a variable, along with a radius value of 25km
loc = '51.50722, -0.1275, 25km'

# scraping 100 recent tweets from London that mention "mental health" and creating a pandas DataFrame 
df_coord = pd.DataFrame(itertools.islice(sntwitter.TwitterSearchScraper(
    'mental health geocode:"{}"'.format(loc)).get_items(), 100))

df_coord.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/dmcfender/status/158208235...
# 1  https://twitter.com/SandLTH/status/15820810156...
# 2  https://twitter.com/felthambboy/status/1582080...
# 3  https://twitter.com/GaReth_Rutter/status/15820...
# 4  https://twitter.com/eamonnpmcmahon/status/1582...
#
#                        date  \
# 0 2022-10-17 18:53:22+00:00
# 1 2022-10-17 18:48:02+00:00
# 2 2022-10-17 18:47:09+00:00
# 3 2022-10-17 18:43:32+00:00
# 4 2022-10-17 18:43:19+00:00
#
#                                              content  \
# 0  Truss is beginning to show all the signs of so...
# 1  We like to encourage people to get outside int...
# 2  Kanye west is a dangerous man with dangerous v...
# 3  @adamskip77 So. Sorry mate. So much I didn’t d...
# 4  There are so many anonymous twitter accounts w...
#
#                                      renderedContent                   id  \
# 0  Truss is beginning to show all the signs of so...  1582082359435808770
# 1  We like to encourage people to get outside int...  1582081015698591744
# 2  Kanye west is a dangerous man with dangerous v...  1582080792507060224
# 3  @adamskip77 So. Sorry mate. So much I didn’t d...  1582079882766733312
# 4  There are so many anonymous twitter accounts w...  1582079827917799424
#
#                                                 user  replyCount  \
# 0  {'username': 'dmcfender', 'id': 3315235678, 'd...           0
# 1  {'username': 'SandLTH', 'id': 3003012933, 'dis...           0
# 2  {'username': 'felthambboy', 'id': 989625924, '...           0
# 3  {'username': 'GaReth_Rutter', 'id': 397265577,...           0
# 4  {'username': 'eamonnpmcmahon', 'id': 106534795...           0
#
#    retweetCount  likeCount  quoteCount  ...  \
# 0             0          0           0  ...
# 1             0          0           0  ...
# 2             0          0           0  ...
# 3             0          0           0  ...
# 4             0          0           0  ...
#
#                                                media retweetedTweet  \
# 0                                               None           None
# 1  [{'previewUrl': 'https://pbs.twimg.com/media/F...           None
# 2                                               None           None
# 3                                               None           None
# 4                                               None           None
#
#   quotedTweet inReplyToTweetId  \
# 0        None              NaN
# 1        None              NaN
# 2        None              NaN
# 3        None     1.582026e+18
# 4        None              NaN
#
#                                        inReplyToUser  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  {'username': 'adamskip77', 'id': 192690577, 'd...
# 4                                               None
#
#                                       mentionedUsers coordinates place  \
# 0                                               None        None  None
# 1                                               None        None  None
# 2                                               None        None  None
# 3  [{'username': 'adamskip77', 'id': 192690577, '...        None  None
# 4                                               None        None  None
#
#         hashtags cashtags
# 0           None     None
# 1  [getoutdoors]     None
# 2           None     None
# 3           None     None
# 4           None     None
#
# [5 rows x 27 columns]

# %%
df_coord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   url               100 non-null    object
#  1   date              100 non-null    datetime64[ns, UTC]
#  2   content           100 non-null    object
#  3   renderedContent   100 non-null    object
#  4   id                100 non-null    int64
#  5   user              100 non-null    object
#  6   replyCount        100 non-null    int64
#  7   retweetCount      100 non-null    int64
#  8   likeCount         100 non-null    int64
#  9   quoteCount        100 non-null    int64
#  10  conversationId    100 non-null    int64
#  11  lang              100 non-null    object
#  12  source            100 non-null    object
#  13  sourceUrl         100 non-null    object
#  14  sourceLabel       100 non-null    object
#  15  outlinks          31 non-null     object
#  16  tcooutlinks       31 non-null     object
#  17  media             19 non-null     object
#  18  retweetedTweet    0 non-null      object
#  19  quotedTweet       9 non-null      object
#  20  inReplyToTweetId  44 non-null     float64
#  21  inReplyToUser     44 non-null     object
#  22  mentionedUsers    58 non-null     object
#  23  coordinates       1 non-null      object
#  24  place             1 non-null      object
#  25  hashtags          29 non-null     object
#  26  cashtags          0 non-null      object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(6), object(19)
# memory usage: 21.2+ KB

# %% [markdown]
# We might want to filter the data further, based on language ("lang"), or date, or popularity/traction the tweet has gained ("likeCount", "retweetCount", etc).

# %% [markdown]
# The "user" column may need to be normalised using json_normalize from pandas.io.json before it can be utilised further.

# %%
# importing json_normalize

from pandas.io.json import json_normalize

import warnings
warnings.filterwarnings("ignore")

# %%
users = json_normalize(df_coord["user"])

users.head()
# Out:
#          username                   id                           displayname  \
# 0       dmcfender           3315235678           Dermz/#torysewagepartyout !
# 1         SandLTH           3003012933  Strength and Learning Through Horses
# 2     felthambboy            989625924                                   Tom
# 3   GaReth_Rutter            397265577                         Gareth Rutter
# 4  eamonnpmcmahon  1065347954297442304                        Eamonn McMahon
#
#                                          description  \
# 0  Angry Pro European ..Uber driver, more people ...
# 1  We're a unique London charity helping young pe...
# 2  Brentford Football Club are premier League.  a...
# 3  Founder and Creative Director @BellowStudio - ...
# 4  fintech / ex investment banking / Gin, Jazz an...
#
#                                       rawDescription  \
# 0  Angry Pro European ..Uber driver, more people ...
# 1  We're a unique London charity helping young pe...
# 2  Brentford Football Club are premier League.  a...
# 3  Founder and Creative Director @BellowStudio - ...
# 4  fintech / ex investment banking / Gin, Jazz an...
#
#                                      descriptionUrls  verified  \
# 0                                               None     False
# 1                                               None     False
# 2                                               None     False
# 3  [{'text': 'bellow.studio', 'url': 'http://bell...     False
# 4                                               None     False
#
#                     created  followersCount  friendsCount  ...  \
# 0 2015-06-09 15:40:41+00:00             825          1792  ...
# 1 2015-01-28 11:56:11+00:00             629           518  ...
# 2 2012-12-04 21:37:46+00:00             640          3042  ...
# 3 2011-10-24 13:18:14+00:00            3125          4830  ...
# 4 2018-11-21 20:55:20+00:00             172           158  ...
#
#    favouritesCount  listedCount  mediaCount           location protected  \
# 0            24278            2          24             london     False
# 1             3450           15        2767    Edgware, London     False
# 2             3956           11        4001  South west London     False
# 3            15781           58        6440             London     False
# 4             7168            0         170    London, England     False
#
#                                             linkUrl               linkTcourl  \
# 0                                              None                     None
# 1  http://www.strengthandlearningthroughhorses.org/  https://t.co/DDorXyWTnI
# 2                                              None                     None
# 3                                              None                     None
# 4                             http://www.equipal.co  https://t.co/YOPQbLN96l
#
#                                      profileImageUrl  \
# 0  https://pbs.twimg.com/profile_images/134433624...
# 1  https://pbs.twimg.com/profile_images/130626432...
# 2  https://pbs.twimg.com/profile_images/148220909...
# 3  https://pbs.twimg.com/profile_images/155668183...
# 4  https://pbs.twimg.com/profile_images/157561270...
#
#                                     profileBannerUrl label
# 0  https://pbs.twimg.com/profile_banners/33152356...  None
# 1  https://pbs.twimg.com/profile_banners/30030129...  None
# 2  https://pbs.twimg.com/profile_banners/98962592...  None
# 3  https://pbs.twimg.com/profile_banners/39726557...  None
# 4  https://pbs.twimg.com/profile_banners/10653479...  None
#
# [5 rows x 21 columns]

# %% [markdown]
# Interestingly, the "location" values for the users in the first five rows seem to be London.
# That is good to note.

# %% [markdown]
# To be continued...

# %% [markdown]
# References:
#
# - https://www.kaggle.com/code/prathamsharma123/clean-raw-json-tweets-data/notebook
# - https://betterprogramming.pub/how-to-scrape-tweets-with-snscrape-90124ed006af
# - https://medium.com/swlh/how-to-scrape-tweets-by-location-in-python-using-snscrape-8c870fa6ec25
# - https://github.com/JustAnotherArchivist/snscrape
